# %% [markdown]
# # Discovering Islands
#
# ## Project Narrative:
# Project is based on the following information from the Kaggle Dataset.<br />
# [From Kaggle:](https://www.kaggle.com/datasets/adityakishor1/all-countries-details)
# About Dataset: <br />
# Here you get all the details of any country.<br />
# like (continent, Country, capital city, latitude, longitude, agricultural land) etc.<br />
#
# It would be an immense task to provide a detailed description of every country on Earth in a single response. However, I can provide you with a concise overview of each country, sorted alphabetically. Keep in mind that this will be very brief, and for up-to-date and detailed information, you should refer to reputable sources like government websites, encyclopedias, or travel guides.
#
# ## Additional Notes:
# I wanted a way to cut up the data even more so I added the 'Is Island' (isIsland column). Boolean value, where 0=false (not an island) and 1=true(is an island)<br />
# I also wanted to isolate island chains in such a way that I could view information for the West Indies alone.  Originally I was going to refer to them as the 'Caribbean', however, there are some mainland costals that are referred to as 'Caribbean', whereas the 'West Indies' are specifically the island chains.<br />
#
# ## DATA DICTIONARY:
# country: Name of the country. <br />
# isIsland: I added this column so I could split the data out to examine islands. <br />
# isWestIndies: Another column I added so I could split out the data to examine by island chains in the Caribbean. <br />
# country_long: Long description of the country. <br />
# currency: Currency related to the country. <br />
# capital_city: Capitol city of countries. <br />
# region: related Region <br />
# continent: continent detail <br />
# demonym: name for the inhabitants. <br />
# latitude: local latitude <br />
# longitude: local longitude <br />
# agricultural_land: total agricultural land. <br />
# forest_area: total forested area. <br />
# land_area: total land area. <br />
# rural_land: land dedicated to rural development. <br />
# urban_land: land dedicated to urban development. <br />
# central_government_debt_pct_gdp: Central government debt, total percentage of GDP.  [DEFINITION](https://data.oecd.org/gga/general-government-debt.htm) <br />
# expense_pct_gdp: Government spending as a percentage of GDP.[DEFINITION](https://corporatefinanceinstitute.com/resources/economics/government-spending/) <br />
# gdp: Gross Domestic Product of country. [DEFINITION](https://www.investopedia.com/terms/g/gdp.asp) <br />
# inflation: Inflation  of country. <br />
# self_employed_pct: Percentage of the country self-employed.<br />
# tax_revenue_pct_gdp: Tax Revenue as a percentage of the GDP. <br />
# unemployment_pct: Percentage of unemployment of the country. <br />
# vulnerable_employment_pct: percentage of population without formal work agreements<br />
# electricity_access_pct: <br />
# alternative_nuclear_energy_pct: <br />
# electricty_production_coal_pct: <br />
# electricty_production_hydroelectric_pct: <br />
# electricty_production_gas_pct: <br />
# electricty_production_nuclear_pct: <br />
# electricty_production_oil_pct: <br />
# electricty_production_renewable_pct: <br />
# energy_imports_pct: <br />
# fossil_energy_consumption_pct: <br />
# renewable_energy_consumption_pct: <br />
# co2_emissions: <br />
# methane_emissions: <br />
# nitrous_oxide_emissions: <br />
# greenhouse_other_emissions: <br />
# urban_population_under_5m: <br />
# health_expenditure_pct_gdp: <br />
# health_expenditure_capita: <br />
# hospital_beds: <br />
# hiv_incidence: <br />
# suicide_rate: <br />
# armed_forces: <br />
# internally_displaced_persons: <br />
# military_expenditure_pct_gdp: <br />
# birth_rate: <br />
# death_rate: <br />
# fertility_rate: <br />
# internet_pct: <br />
# life_expectancy: <br />
# net_migration: <br />
# population_female: <br />
# population_male: <br />
# population: <br />
# women_parliament_seats_pct: <br />
# rural_population: <br />
# urban_population: <br />
# press: <br />
# democracy_score: <br />
# democracy_type: <br />
# median_age: <br />
# political_leader: <br />
# title: <br />

# %%
# import appropriate package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# bring in the data set:
path="allCountries.csv"

# %%
# create the dataframe and check for data
ds=pd.read_csv(path)
ds.head()
# Out:
#        country  isIsland  isWestIndies  \
# 0  Afghanistan         0             0
# 1      Albania         0             0
# 2      Algeria         0             0
# 3      Andorra         0             0
# 4       Angola         0             0
#
#                               country_long        currency      capital_city  \
# 0             Islamic State of Afghanistan  Afghan afghani             Kabul
# 1                      Republic of Albania    Albanian lek            Tirana
# 2  People's Democratic Republic of Algeria  Algerian dinar           Algiers
# 3                  Principality of Andorra            Euro  Andorra la Vella
# 4              People's Republic of Angola  Angolan kwanza            Luanda
#
#             region continent   demonym  latitude  ...  population  \
# 0    Southern Asia      Asia    Afghan      33.0  ...    41128771
# 1  Southern Europe    Europe  Albanian      41.0  ...     2775634
# ...

# %% [markdown]
# ## Sanity Checks
# ### Island Dataframe

# %%
# Create a new dataframe with just the islands
ds_isl = ds[ds['isIsland'] == 1]
ds_isl.head()
# Out:
#                 country  isIsland  isCaribbean            country_long  \
# 5   Antigua and Barbuda         1            1     Antigua and Barbuda
# 11              Bahrain         1            0      Kingdom of Bahrain
# 13             Barbados         1            1                Barbados
# 27           Cabo Verde         1            0  Republic of Cabo Verde
# 36              Comoros         1            0    Union of the Comoros
#
#                  currency  capital_city          region continent  \
# 5   East Caribbean dollar  Saint John's       Caribbean  Americas
# 11         Bahraini dinar        Manama    Western Asia      Asia
# 13        Barbados dollar    Bridgetown       Caribbean  Americas
# 27      Cabo Verde escudo         Praia  Western Africa    Africa
# 36         Comorian franc        Moroni  Eastern Africa    Africa
#
#          demonym   latitude  ...  population  women_parliament_seats_pct  \
# ...

# %%
column_names=list(ds_isl.columns.values)
print(f"The column headers :\n{column_names}\n")
# Out:
# The column headers :
# ...

# %%
ds_isl.nunique()
# Out:
# country             45
# isIsland             1
# isCaribbean          2
# country_long        45
# currency            33
#                     ..
# democracy_score     25
# democracy_type       5
# median_age          41
# political_leader    40
# title                5
# Length: 66, dtype: int64

# %%
ds_isl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 5 to 187
# Data columns (total 66 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  45 non-null     object
#  1   isIsland                                 45 non-null     int64
#  2   isCaribbean                              45 non-null     int64
#  3   country_long                             45 non-null     object
#  4   currency                                 45 non-null     object
#  5   capital_city                             45 non-null     object
#  6   region                                   45 non-null     object
#  7   continent                                45 non-null     object
#  8   demonym                                  45 non-null     object
#  9   latitude                                 45 non-null     float64
# ...

# %%
ds_isl.describe().T
# Out:
#                                          count          mean           std  \
# isIsland                                  45.0  1.000000e+00  0.000000e+00
# isCaribbean                               45.0  2.888889e-01  4.583678e-01
# latitude                                  45.0  8.544815e+00  2.113640e+01
# longitude                                 45.0  3.572926e+01  1.022650e+02
# agricultural_land                         45.0  3.798055e+04  1.125053e+05
# forest_area                               45.0  4.477500e+04  1.495275e+05
# land_area                                 45.0  1.026723e+05  3.006951e+05
# rural_land                                45.0  9.963922e+04  2.924039e+05
# urban_land                                45.0  3.933831e+03  1.301658e+04
# central_government_debt_pct_gdp           31.0  6.922107e+01  4.909385e+01
# expense_pct_gdp                           36.0  3.377171e+01  2.064166e+01
# ...

# %%
ds_isl.isnull().sum()
# Out:
# country             0
# isIsland            0
# isCaribbean         0
# country_long        0
# currency            0
#                    ..
# democracy_score     0
# democracy_type      0
# median_age          0
# political_leader    5
# title               5
# Length: 66, dtype: int64

# %%
print(ds_isl["country"].value_counts())
# Out:
# country
# Antigua and Barbuda               1
# Micronesia                        1
# New Zealand                       1
# Palau                             1
# Papua New Guinea                  1
# Philippines                       1
# Samoa                             1
# São Tomé and Principe             1
# Seychelles                        1
# Singapore                         1
# Solomon Islands                   1
# Sri Lanka                         1
# St. Kitts and Nevis               1
# St. Lucia                         1
# St. Vincent and the Grenadines    1
# The Bahamas                       1
# Timor-Leste                       1
# Tonga                             1
# Trinidad and Tobago               1
# Tuvalu                            1
# United Kingdom                    1
# Nauru                             1
# Mauritius                         1
# Bahrain                           1
# Marshall Islands                  1
# Barbados                          1
# ...

# %% [markdown]
# ### West Indies Dataframe
# * The West Indies are the island groups located in the Caribbean.  While the word 'Caribbean' refers to the area in a general sense and can include coastal mainland portions for the area, the term 'West Indies' refers to the  island groups themselves.

# %%
ds_carib = ds[ds['isWestIndies'] == 1]
ds_carib.head()
# Out:
#                 country  isIsland  isWestIndies              country_long  \
# 5   Antigua and Barbuda         1             1       Antigua and Barbuda
# 13             Barbados         1             1                  Barbados
# 41                 Cuba         1             1          Republic of Cuba
# 48             Dominica         1             1  Commonwealth of Dominica
# 49   Dominican Republic         1             1        Dominican Republic
#
#                  currency   capital_city     region continent    demonym  \
# 5   East Caribbean dollar   Saint John's  Caribbean  Americas   Antiguan
# 13        Barbados dollar     Bridgetown  Caribbean  Americas  Barbadian
# 41             Cuban peso         Havana  Caribbean  Americas      Cuban
# 48  East Caribbean dollar         Roseau  Caribbean  Americas  Dominican
# 49         Dominican peso  Santo Domingo  Caribbean  Americas  Dominican
#
#      latitude  ...  population  women_parliament_seats_pct  rural_population  \
# ...

# %%
# Print out all the Islands classified in the West Indies:
print(f'The following list of islands in the West Indies:\n {ds_carib["country"]}\n\n')
# Out:
# The following list of islands in the West Indies:
#  5                 Antigua and Barbuda
# 13                           Barbados
# 41                               Cuba
# 48                           Dominica
# 49                 Dominican Republic
# 66                            Grenada
# 71                              Haiti
# 82                            Jamaica
# 159               St. Kitts and Nevis
# 160                         St. Lucia
# 161    St. Vincent and the Grenadines
# 170                       The Bahamas
# 175               Trinidad and Tobago
# Name: country, dtype: object

# %%
ds_carib.describe().T
# Out:
#                                          count          mean           std  \
# isIsland                                  13.0  1.000000e+00  0.000000e+00
# isWestIndies                              13.0  1.000000e+00  0.000000e+00
# latitude                                  13.0  1.655513e+01  3.880939e+00
# longitude                                 13.0 -6.667949e+01  7.467427e+00
# agricultural_land                         13.0  8.659185e+03  1.841923e+04
# forest_area                               13.0  5.545108e+03  9.959694e+03
# land_area                                 13.0  1.606615e+04  2.994123e+04
# rural_land                                13.0  1.593792e+04  3.036799e+04
# urban_land                                13.0  7.219116e+02  1.015584e+03
# central_government_debt_pct_gdp            8.0  6.611238e+01  4.499606e+01
# expense_pct_gdp                            8.0  2.588409e+01  5.829321e+00
# ...

# %%
ds_carib.isnull().sum()
# Out:
# country             0
# isIsland            0
# isWestIndies        0
# country_long        0
# currency            0
#                    ..
# democracy_score     0
# democracy_type      0
# median_age          0
# political_leader    3
# title               3
# Length: 66, dtype: int64

# %%
print(ds_carib["political_leader"])
# Out:
# 5          Gaston Browne
# 13           Mia Mottley
# 41           Raúl Castro
# 48     Roosevelt Skerrit
# 49         Danilo Medina
# 66        Keith Mitchell
# 71         Jovenel Moïse
# 82        Andrew Holness
# 159                  NaN
# 160                  NaN
# 161                  NaN
# 170        Hubert Minnis
# 175         Keith Rowley
# Name: political_leader, dtype: object

# %% [markdown]
# ### OBSERVATIONS:
#  13 countries in the dataset are identified as being located in the Caribbean.

# %% [markdown]
# ## Exploratory Data Analysis:

# %%
# Lorem Ipsum

# %% [markdown]
# ### Univariate Analysis

# %%
# Lorem ipsum

# %% [markdown]
# ### Bivariate Analysis

# %%
# Lorem Ipsum
